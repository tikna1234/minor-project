# %%
import random as rndm
import pandas as pd
import numpy as np
data = pd.read_excel(r"C:\Users\HP\Documents\GitHub\minor-project\Datasets\english_questions.xlsx")

# %%
data
# Out:
#                                              Question  \
# 0   Which of the following is a synonym for 'intel...
# 1       Which of the following words is a determiner?
# 2   Identify the sentence with the correct subject...
# 3   What is the correct transformation of the sent...
# 4   Choose the appropriate modal verb for the foll...
# 5   Which of the following is the correct verb for...
# 6   Identify the sentence that is grammatically co...
# 7   Choose the correct reported speech version of ...
# 8   What is the appropriate determiner for the sen...
# 9   Choose the correct form of the verb for the se...
# 10  What is the correct reported speech version of...
# 11        Which sentence has the correct punctuation?
# 12  What is the appropriate determiner for the sen...
# 13  Choose the correct modal verb for the sentence...
# 14  Identify the sentence with the correct use of ...
# 15  What is the appropriate determiner for the sen...
# 16  Choose the correct transformation of the sente...
# 17  What is the appropriate determiner for the sen...
# 18  Choose the correct form of the verb for the se...
# 19     Which of the following sentences is a command?
# 20  What is the correct transformation of the sent...
# 21  Choose the correct form of the verb for the se...
# 22  Identify the sentence that has the correct sub...
# 23  What is the appropriate determiner for the sen...
# 24  Choose the correct modal verb for the sentence...
# 25  Identify the sentence with the correct use of ...
# 26  Which tense is used to express actions that oc...
# 27  What preposition is used to express movement f...
# 28  Identify the sentence with the correct use of ...
# 29  What is the passive voice of the sentence 'She...
# 30  What is the one-word substitution for the phra...
# 31  Choose the sentence that uses the correct homo...
# 32          What is the synonym for the word 'Ample'?
# 33  Identify the idiom in the sentence 'He is feel...
# 34  In which sentence is the error spotted and cor...
# 35  What is the letter writing format used for inf...
# 36             What is the purpose of precis writing?
# 37  Identify the sentence with the correct use of ...
# 38  Which article is used before words that start ...
# 39  What is the reported speech version of the sen...
# 40  What is the sentence rearrangement of the foll...
# 41  What is the error in the sentence 'She sings g...
# 42  What is the comparative degree of the adjectiv...
# 43  What is the function of the indefinite article...
# 44  What is the direct speech version of the sente...
# 45  What is the appropriate arrangement of the sen...
# 46  Choose the sentence with the correct use of th...
# 47  What is the superlative degree of the adjectiv...
# 48  Identify the sentence with the correct use of ...
# 49           What is the synonym for the word 'Huge'?
# 50  Choose the appropriate use of the idiom 'Bite ...
#
#                                           OptionA  \
# 0                                          Stupid
# 1                                          a) Run
# 2                  a) The dogs is barking loudly.
# 3      a) He says that he is going to the market.
# 4                                         a) must
# 5                                        a) reads
# 6                    a) She don't like ice cream.
# 7              a) She asked if he could help her.
# 8                                         a) Much
# 9                                        a) rides
# 10         a) He says that he will come tomorrow.
# 11              a) The cat is brown its sleeping.
# 12                                         a) Few
# 13                                       a) might
# 14                 a) He said, 'I will help you.'
# 15                                     a) Several
# 16          a) She told me to help her with that.
# 17                                        a) Many
# 18                                          a) go
# 19                      a) Will you come with me?
# 20      a) He says that he has finished his work.
# 21                                        a) does
# 22             a) The birds is flying in the sky.
# 23                                        a) Many
# 24                                        a) will
# 25                  a) He says, 'I can help you.'
# 26                                  Present tense
# 27                                          Above
# 28                       He likes tea nor coffee.
# 29                   A letter was written by her.
# 30                                         Aviary
# 31        He heard the bell peal in the distance.
# 32                                         Scarce
# 33                                A piece of cake
# 34       Each of the boys are going to the party.
# 35  Heading, Salutation, Body, Closing, Signature
# 36                         To summarize a passage
# 37          She is the most smarter in her class.
# 38                                             An
# 39            He said that he will come tomorrow.
# 40                      East the sun rises in the
# 41            The use of 'good' instead of 'well'
# 42                                 More beautiful
# 43                    To refer to a specific item
# 44          She said, 'I am going to the market.'
# 45          A book in the garden she was reading.
# 46         She will not come so he will go alone.
# 47                                         Better
# 48         He sat besides her during the concert.
# 49                                           Tiny
# 50        He bit the bullet to complete the task.
#
#                                             OptionB  \
# 0                                            Clever
# 1                                            b) The
# 2                    b) The dog are barking loudly.
# 3       b) He says that he was going to the market.
# 4                                            b) can
# 5                                           b) read
# 6                  b) They doesn't know the answer.
# 7                  b) She asked if he can help her.
# 8                                            b) Any
# 9                                      b) is riding
# 10          b) He says that he would come tomorrow.
# 11              b) The cat is brown, it's sleeping.
# 12                                          b) Much
# 13                                        b) should
# 14                  b) He said, 'He will help you.'
# 15                                           b) Any
# 16            b) She told me to help her with this.
# 17                                           b) Few
# 18                                          b) went
# 19                               b) Please help me.
# 20        b) He said that he had finished his work.
# 21                                           b) did
# 22                   b) The bird is fly in the sky.
# 23                                          b) Some
# 24                                           b) can
# 25                   b) He says, 'He can help you.'
# 26                                       Past tense
# 27                                           Across
# 28         She is both intelligent but hardworking.
# 29                A letter has been written by her.
# 30                                        Sanctuary
# 31         He heard the belle peal in the distance.
# 32                                       Sufficient
# 33                                  Kick the bucket
# 34  The book, as well as the pen, was on the table.
# 35    Salutation, Heading, Body, Closing, Signature
# 36                           To critique an article
# 37            He is the smartest boy in the school.
# 38                                              The
# 39              He says that he will come tomorrow.
# 40                        In the east sun rises the
# 41                         The absence of a subject
# 42                                      Beautifuler
# 43                         To refer to a known item
# 44          She said, 'She is going to the market.'
# 45            In the garden she was reading a book.
# 46        He wanted to eat both ice cream and cake.
# 47                                        Most good
# 48                        The book is on the table.
# 49                                          Massive
# 50             The bullet bit him during the fight.
#
#                                               OptionC  \
# 0                                                Dull
# 1                                        c) Beautiful
# 2                     c) The dogs are barking loudly.
# 3           c) He says that he will go to the market.
# 4                                             c) will
# 5                                       c) is reading
# 6             c) I am not understanding this concept.
# 7                   c) She asked if he will help her.
# 8                                             c) Some
# 9                                             c) rode
# 10             c) He said that he will come tomorrow.
# 11                  c) The cat is brown its sleeping.
# 12                                            c) Many
# 13                                            c) need
# 14                   c) He said, 'He would help you.'
# 15                                          c) Little
# 16             c) She asked me to help her with that.
# 17                                          c) Little
# 18                                            c) goes
# 19                               c) Don't touch that.
# 20          c) He says that he had finished his work.
# 21                                              c) do
# 22                c) The birds are flying in the sky.
# 23                                             c) Any
# 24                                             c) may
# 25                   c) He says, 'He could help you.'
# 26                                       Future tense
# 27                                              Among
# 28       They can play either football or basketball.
# 29                        A letter is written by her.
# 30                                               Cage
# 31            He heard the bell peel in the distance.
# 32                                             Meager
# 33                                      Break the ice
# 34  The teacher, along with the students, are plan...
# 35      Heading, Body, Salutation, Closing, Signature
# 36                              To paraphrase a story
# 37         The tree is more taller than the building.
# 38                                                  A
# 39               He said that he would come tomorrow.
# 40                          Rises in the east sun the
# 41                           The absence of an object
# 42                                      Beautifullest
# 43                        To refer to an unknown item
# 44           She said, 'She was going to the market.'
# 45              In the garden a book she was reading.
# 46                     I like neither tea nor coffee.
# 47                                               Best
# 48                       We walked through the river.
# 49                                              Small
# 50                 He took the bullet out of the gun.
#
#                                           OptionD Answer
# 0                                        Ignorant      B
# 1                                      d) Quickly      B
# 2                   d) The dog is barking loudly.      C
# 3      d) He said that he is going to the market.      B
# 4                                           d) do      A
# 5                                     d) has read      A
# 6             d) He plays football every evening.      D
# 7              d) She asked if he would help her.      A
# 8                                          d) All      D
# 9                                   d) has ridden      C
# 10        d) He said that he would come tomorrow.      D
# 11             d) The cat is brown it's sleeping.      B
# 12                                        d) Some      D
# 13                                       d) would      B
# 14                    d) He said, 'He helps you.'      A
# 15                                         d) All      A
# 16         d) She asked me to help her with this.      B
# 17                                        d) Much      C
# 18                                    d) is going      B
# 19                         d) Are you going home?      C
# 20      d) He said that he has finished his work.      B
# 21                                    d) is doing      A
# 22                d) The bird are fly in the sky.      C
# 23                                        d) Much      D
# 24                                      d) should      D
# 25                    d) He says, 'He helps you.'      A
# 26                                  Perfect tense      B
# 27                                           Into      D
# 28      I don't like him because he is not funny.      C
# 29              A letter had been written by her.      A
# 30                                           Nest      A
# 31     He heard the bell peeling in the distance.      A
# 32                                         Sparse      B
# 33                              Under the weather      D
# 34        The dog and the cat has become friends.      B
# 35  Salutation, Body, Closing, Heading, Signature      A
# 36                              To analyze a poem      A
# 37      It is the goodest movie I have ever seen.      B
# 38                              None of the above      A
# 39           He says that he would come tomorrow.      C
# 40                      In the east rises the sun      D
# 41                          The absence of a verb      A
# 42                                 Most beautiful      A
# 43                      To refer to a plural item      C
# 44         She said, 'She will go to the market.'      C
# 45          Reading a book she was in the garden.      B
# 46  They were neither good at studies nor sports.      C
# 47                                         Gooder      C
# 48                           She lives at Mumbai.      B
# 49                                         Minute      B
# 50                      He threw the bullet away.      A

# %%
for x in range(5):
    q=data.iloc[x,0]
    print(q)
    print(q)
    a=data.iloc[x,1]
    print(a)
    b=data.iloc[x,2]
    print(b)
    c=data.iloc[x,3]
    print(c)
    d=data.iloc[x,4]
    print(d)
# Out:
# Which of the following is a synonym for 'intelligent'?
# Which of the following is a synonym for 'intelligent'?
# Stupid
# Clever
# Dull
# Ignorant
# Which of the following words is a determiner?
# Which of the following words is a determiner?
# a) Run
# b) The
# c) Beautiful
# d) Quickly
# Identify the sentence with the correct subject-verb agreement.
# Identify the sentence with the correct subject-verb agreement.
# a) The dogs is barking loudly.
# b) The dog are barking loudly.
# c) The dogs are barking loudly.
# d) The dog is barking loudly.
# What is the correct transformation of the sentence 'He said, 'I am going to the market'' into reported speech?
# What is the correct transformation of the sentence 'He said, 'I am going to the market'' into reported speech?
# a) He says that he is going to the market.
# b) He says that he was going to the market.
# c) He says that he will go to the market.
# d) He said that he is going to the market.
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do

# %%
english = []
while(len(english)!=25):
    r = rndm.randint(0,50)
    if(r not in english):
        english.append(r)
    else:
        continue
print(english)
for i in english:
    q=data.iloc[x,0]
    print("question ",i)
    print(q)
    a=data.iloc[x,1]
    print(a)
    b=data.iloc[x,2]
    print(b)
    c=data.iloc[x,3]
    print(c)
    d=data.iloc[x,4]
    print(d)
    print(" ")
# Out:
# [6, 21, 32, 29, 9, 30, 24, 44, 19, 14, 40, 4, 12, 45, 11, 37, 28, 39, 31, 8, 16, 25, 41, 5, 42]
# question  6
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  21
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  32
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  29
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  9
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  30
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  24
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  44
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  19
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  14
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  40
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  4
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  12
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  45
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  11
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  37
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  28
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  39
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  31
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  8
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  16
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  25
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  41
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  5
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do
#
# question  42
# Choose the appropriate modal verb for the following sentence: 'You __ finish your homework before you watch TV.'
# a) must
# b) can
# c) will
# d) do

# %%
###we will create a count variable which will be increment by clicking next button and get decremented by clicking back button and 
###print the questions according to value of count variable.

# %%
ans=[]
for i in english:
    ans.append(data.iloc[i,5])
print(ans)
rsp=[]
marks = 0
for i in range(25):
    if(rsp[i]==ans[i]):
        marks=marks+4
# Out:
# ['D', 'A', 'B', 'A', 'C', 'A', 'D', 'C', 'C', 'A', 'D', 'A', 'D', 'B', 'B', 'B', 'C', 'C', 'A', 'D', 'B', 'A', 'A', 'A', 'A']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[73], line 8
#       6 marks = 0
#       7 for i in range(25):
# ----> 8     if(rsp[i]==ans[i]):
#       9         marks=marks+4
#
# IndexError: list index out of range
