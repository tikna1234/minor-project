# %%
import pandas as pd
tips = pd.read_excel(r"C:\Users\HP\Documents\GitHub\minor-project\Datasets\Tips_all_subjects.xlsx")

# %%
tips
# Out:
#              subject                                               tip1  \
# 0            English  Read Regularly: Reading books, newspapers, and...
# 1        Mathematics  Practice Regularly: Mathematics is a subject t...
# 2            Science  Hands-On Learning: Perform experiments and pra...
# 3     Social_Studies  Note-Taking: Keep organized notes to help with...
# 4  Logical_Reasoning  Puzzle Solving: Solve puzzles and brain teaser...
# 5           Computer  Hands-On Practice: Use computers regularly. Pr...
#
#                                                 tip2  \
# 0  Writing Practice: Regularly write essays, stor...
# 1  Understand Concepts: Ensure that you understan...
# 2  Visual Aids: Use diagrams, charts, and videos ...
# 3  Concept Mapping: Create concept maps to unders...
# 4  Critical Thinking: Analyze situations critical...
# 5  Stay Informed: Keep up with the latest develop...
#
#                                                 tip3
# 0  Grammar and Vocabulary: Focus on improving gra...
# 1  Use Resources: Utilize textbooks, online resou...
# 2  Question and Discuss: Ask questions and engage...
# 3  Stay Updated: Keep looking current affairs, as...
# 4  Practice Mock Tests: If applicable, practice l...
# 5  Online Courses: Consider taking online courses...

# %%
tips.set_index('subject')
# Out:
#                                                                 tip1  \
# subject
# English            Read Regularly: Reading books, newspapers, and...
# Mathematics        Practice Regularly: Mathematics is a subject t...
# Science            Hands-On Learning: Perform experiments and pra...
# Social_Studies     Note-Taking: Keep organized notes to help with...
# Logical_Reasoning  Puzzle Solving: Solve puzzles and brain teaser...
# Computer           Hands-On Practice: Use computers regularly. Pr...
#
#                                                                 tip2  \
# subject
# English            Writing Practice: Regularly write essays, stor...
# Mathematics        Understand Concepts: Ensure that you understan...
# Science            Visual Aids: Use diagrams, charts, and videos ...
# Social_Studies     Concept Mapping: Create concept maps to unders...
# Logical_Reasoning  Critical Thinking: Analyze situations critical...
# Computer           Stay Informed: Keep up with the latest develop...
#
#                                                                 tip3
# subject
# English            Grammar and Vocabulary: Focus on improving gra...
# Mathematics        Use Resources: Utilize textbooks, online resou...
# Science            Question and Discuss: Ask questions and engage...
# Social_Studies     Stay Updated: Keep looking current affairs, as...
# Logical_Reasoning  Practice Mock Tests: If applicable, practice l...
# Computer           Online Courses: Consider taking online courses...

# %%
weak = ['Mathematics']
a=[]
for i in weak:
    a.append(tips.loc[i])
    
len(a)
# Out:
# 1
